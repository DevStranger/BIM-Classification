# %%
# Importy + konfig
import pandas as pd
import json
from sentence_transformers import SentenceTransformer, util
from tqdm import tqdm

# %%
# Wczytanie modelu
model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# %%
# Wczytanie i przygotowanie klas bSDD
with open("../data/bsdd_cleared.json", "r", encoding="utf-8") as f:
    raw_data = json.load(f)

flattened_classes = []
for entry in raw_data:
    dictionary_name = entry["dictionary_name"]
    for cls in entry["classes"]:
        cls["dictionary_name"] = dictionary_name
        flattened_classes.append(cls)

bsdd_df = pd.DataFrame(flattened_classes)

bsdd_df["full_text"] = (
    bsdd_df["class_code"].astype(str) + " — " +
    bsdd_df["class_name"].fillna("") + " — " +
    bsdd_df["class_description"].fillna("")
)

bsdd_embeddings = model.encode(bsdd_df["full_text"].tolist(), convert_to_tensor=True)

# %%
# Wczytanie danych IFC z parsera
ifc_df = pd.read_csv("../data/ifc_objects.csv")
ifc_df.head()
# Out:
#                  GlobalId  IfcType                                    Name  \
# 0  3zR0BOEcLADRKln4HYporH  IFCSLAB                                   floor
# 1  1AQAupaRP1txwK1AGiN61V  IFCWALL  house - outer wall - house right front
# 2  3wdauVJT5Fx9drrREiDqA$  IFCWALL   house - outer wall - house right back
# 3  0OfZwWc8j9QP5uX8xPTxDH  IFCWALL         house - outer wall - house left
# 4  1uS5vfZPn9R8PlAaVd73on  IFCWALL                           plumbing wall
#
#                                                 Text
# 0  A solid, site-cast concrete floor, providing a...
# 1  A solid outer wall, forming the right front si...
# 2  A solid outer wall, forming the right back sid...
# 3  A solid outer wall, forming the left side of t...
# 4  A wall designed to house and protect plumbing ...

# %%
# Przygotowanie danych do klasyfikacji + embeddingi
ifc_df["full_text"] = (
    ifc_df["IfcType"].fillna('') + " — " +
    ifc_df["Name"].fillna('') + " — " +
    ifc_df["Text"].fillna('')
)

ifc_embeddings = model.encode(ifc_df["full_text"].tolist(), convert_to_tensor=True)

# %%
# Liczenie podobieństwa kosinusowego
results = []

for i, ifc_emb in enumerate(tqdm(ifc_embeddings)):
    similarities = util.cos_sim(ifc_emb, bsdd_embeddings)[0]
    best_idx = similarities.argmax().item()
    best_score = similarities[best_idx].item()

    results.append({
        "GlobalId": ifc_df.loc[i, "GlobalId"],
        "IfcType": ifc_df.loc[i, "IfcType"],
        "Name": ifc_df.loc[i, "Name"],
        "Opis_IFC": ifc_df.loc[i, "Text"],
        "Kod_bSDD": bsdd_df.loc[best_idx, "class_code"],
        "Nazwa_klasy_bSDD": bsdd_df.loc[best_idx, "class_name"],
        "Słownik": bsdd_df.loc[best_idx, "dictionary_name"],
        "Podobieństwo": round(best_score, 4)
    })

results_df = pd.DataFrame(results)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 304.39it/s]

# %%
# Wyniki
results_df.to_csv("../results/parsed_results.csv", index=False)
results_df.sort_values("Podobieństwo", ascending=False).head(10)
# Out:
#                  GlobalId  IfcType                                    Name  \
# 6  12UVOn4wvAJPMUExKdZLb8  IFCSLAB               house - roof - slab right
# 5  0ZTBBPo6f6bxqV2K7Oelrq  IFCSLAB                house - roof - slab left
# 4  1uS5vfZPn9R8PlAaVd73on  IFCWALL                           plumbing wall
# 0  3zR0BOEcLADRKln4HYporH  IFCSLAB                                   floor
# 1  1AQAupaRP1txwK1AGiN61V  IFCWALL  house - outer wall - house right front
# 3  0OfZwWc8j9QP5uX8xPTxDH  IFCWALL         house - outer wall - house left
# 2  3wdauVJT5Fx9drrREiDqA$  IFCWALL   house - outer wall - house right back
#
#                                             Opis_IFC     Kod_bSDD  \
# 6  A roof slab that's got it all covered. IsExter...  Ac_15_50_73
# 5  A roof slab that's got it all covered. IsExter...  Ac_15_50_73
# 4  A wall designed to house and protect plumbing ...     EC000073
# 0  A solid, site-cast concrete floor, providing a...         L-BA
# 1  A solid outer wall, forming the right front si...     EC000073
# 3  A solid outer wall, forming the left side of t...         L-BE
# 2  A solid outer wall, forming the right back sid...     EC000350
#
#                   Nazwa_klasy_bSDD   Słownik  Podobieństwo
# 6                   Roof surveying  Uniclass        0.6207
# 5                   Roof surveying  Uniclass        0.6142
# 4       Junction box for wall duct      ETIM        0.5653
# 0            Groundworks structure       CCI        0.5432
# 1       Junction box for wall duct      ETIM        0.5261
# 3                   Roof structure       CCI        0.5236
# 2  Mounting frame for door station      ETIM        0.5217
